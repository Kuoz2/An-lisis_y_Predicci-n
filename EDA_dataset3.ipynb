# %% [markdown]
# <a href="https://colab.research.google.com/github/Kuoz2/An-lisis_y_Predicci-n/blob/main/EDA_dataset3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style="whitegrid")


dk_clima= pd.read_csv("/content/drive/MyDrive/CURSOPYTHON/DailyDelhiClimateTest.csv")

# %%
dk_clima.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1  2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2  2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3  2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4  2017-01-05  18.388889  74.944444    3.300000   1014.333333

# %%
dk_clima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          114 non-null    object
#  1   meantemp      114 non-null    float64
#  2   humidity      114 non-null    float64
#  3   wind_speed    114 non-null    float64
#  4   meanpressure  114 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 4.6+ KB

# %%
dk_clima.describe()
# Out:
#          meantemp    humidity  wind_speed  meanpressure
# count  114.000000  114.000000  114.000000    114.000000
# mean    21.713079   56.258362    8.143924   1004.035090
# std      6.360072   19.068083    3.588049     89.474692
# min     11.000000   17.750000    1.387500     59.000000
# 25%     16.437198   39.625000    5.563542   1007.437500
# 50%     19.875000   57.750000    8.069444   1012.739316
# 75%     27.705357   71.902778   10.068750   1016.739583
# max     34.500000   95.833333   19.314286   1022.809524

# %%
dk_clima.tail(5)
# Out:
#            date  meantemp   humidity  wind_speed  meanpressure
# 109  2017-04-20    34.500  27.500000    5.562500    998.625000
# 110  2017-04-21    34.250  39.375000    6.962500    999.875000
# 111  2017-04-22    32.900  40.900000    8.890000   1001.600000
# 112  2017-04-23    32.875  27.500000    9.962500   1002.125000
# 113  2017-04-24    32.000  27.142857   12.157143   1004.142857

# %%
dk_clima['date'] = pd.to_datetime(d_clima['date'], format='mixed')

# 2. Asignamos la fecha como el índice del DataFrame
dk_clima.set_index('date', inplace=True)
print(f"Tamaño del dataset: {dk_clima.shape[0]} filas y {dk_clima.shape[1]} columnas.")
display(dk_clima.info())
display(dk_clima.head())
# Out:
# Tamaño del dataset: 114 filas y 4 columnas.
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 114 entries, 2017-01-01 to 2017-04-24
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   meantemp      114 non-null    float64
#  1   humidity      114 non-null    float64
#  2   wind_speed    114 non-null    float64
#  3   meanpressure  114 non-null    float64
# dtypes: float64(4)
# memory usage: 4.5 KB
# None
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2017-01-01  15.913043  85.869565    2.743478     59.000000
# 2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 2017-01-05  18.388889  74.944444    3.300000   1014.333333

# %%
dk_clima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 114 entries, 2017-01-01 to 2017-04-24
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   meantemp      114 non-null    float64
#  1   humidity      114 non-null    float64
#  2   wind_speed    114 non-null    float64
#  3   meanpressure  114 non-null    float64
# dtypes: float64(4)
# memory usage: 4.5 KB

# %%
dk_clima.isnull().sum()
# Out:
# meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    0
# dtype: int64

# %%
dk_clima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 114 entries, 2017-01-01 to 2017-04-24
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   meantemp      114 non-null    float64
#  1   humidity      114 non-null    float64
#  2   wind_speed    114 non-null    float64
#  3   meanpressure  114 non-null    float64
# dtypes: float64(4)
# memory usage: 4.5 KB

# %%
display(dk_clima.describe().round(2))
# Out:
#        meantemp  humidity  wind_speed  meanpressure
# count    114.00    114.00      114.00        114.00
# mean      21.71     56.26        8.14       1004.04
# std        6.36     19.07        3.59         89.47
# min       11.00     17.75        1.39         59.00
# 25%       16.44     39.62        5.56       1007.44
# 50%       19.88     57.75        8.07       1012.74
# 75%       27.71     71.90       10.07       1016.74
# max       34.50     95.83       19.31       1022.81

# %%
colmn_objetivo= 'meantemp' if 'meantemp' in dk_clima.columns else dk_clima.columns[0]

# %%
fig, axes= plt.subplots(1, 2, figsize=(15, 5))
sns.histplot(dk_clima[colmn_objetivo], kde=True, ax= axes[0], color='coral')
axes[0].set_title(f'Destribucion de {colmn_objetivo}')
axes[0].set_ylabel('Frecuencia')


sns.boxplot(x=dk_clima[colmn_objetivo], ax=axes[1], color='lightsalmon')
axes[1].set_title(f'Boxplot de {colmn_objetivo}')
# Out:
# Text(0.5, 1.0, 'Boxplot de meantemp')

# %%
plt.figure(figsize=(8, 6))
matriz_corr= dk_clima.corr()
sns.heatmap(matriz_corr, annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1)
plt.title(f"Evolucion de la correciones Metereologicas")
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(dk_clima.index, dk_clima[colmn_objetivo], color='dodgerblue', linewidth=1)
plt.title(f'Evolution Temporal de {colmn_objetivo}')
plt.xlabel('Fecha')
plt.ylabel(colmn_objetivo)
plt.tight_layout()
plt.show()
